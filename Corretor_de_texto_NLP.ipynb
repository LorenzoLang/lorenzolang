# %% [markdown]
# <a href="https://colab.research.google.com/github/LorenzoLang/estudos-ML/blob/main/Corretor_de_texto_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
with open("artigos.txt", "r") as f:
    artigos = f.read()

print(artigos[:100])
# Out:
# imagem
#
# Temos a seguinte classe que representa um usuário no nosso sistema:
#
# java
#
# Para salvar u

# %%
texto_exemplo = "Olá, tudo bem?"
tokens = texto_exemplo.split()

# %%
print(len(tokens))
# Out:
# 3

# %%
print(tokens)
# Out:
# ['Olá,', 'tudo', 'bem?']

# %%
palavras_separadas = nltk.tokenize.word_tokenize(texto_exemplo)
print(palavras_separadas)
# Out:
# ['Olá', ',', 'tudo', 'bem', '?']

# %%
# Criando uma função pra separar apenas os tokens sem pontuação e adiciona-los a lista

def separa_palavras(lista_tokens):
    lista_palavras = []
    for token in lista_tokens:
        if token.isalpha():
            lista_palavras.append(token)
    return lista_palavras

separa_palavras(palavras_separadas)
# Out:
# ['Olá', 'tudo', 'bem']

# %%
lista_tokens = nltk.tokenize.word_tokenize(artigos)
lista_palavras = separa_palavras(lista_tokens) 
print(f'O número de palavras é {len(lista_palavras)}')
# Out:
# O número de palavras é 393914

# %%
def normalizacao(lista_palavras):
  lista_normalizada = []
  for palavra in lista_palavras:
    lista_normalizada.append(palavra.lower())
  return lista_normalizada

lista_normalizada = normalizacao(lista_palavras)
print(lista_normalizada[:10])
# Out:
# ['imagem', 'temos', 'a', 'seguinte', 'classe', 'que', 'representa', 'um', 'usuário', 'no']

# %%
# Olhando a quantidade de palavras únicas no nosso documento

len(set(lista_normalizada))
# Out:
# 17652

# %%
palavra_exemplo = "lgica"

def insere_letras(fatias):
    novas_palavras = []
    letras = 'abcdefghijklmnopqrstuvwxyzàáâãèéêìíîòóôõùúûç'
    for E, D in fatias:
        for letra in letras:
            novas_palavras.append(E + letra + D)
        return novas_palavras

def gerador_palavras(palavra):
    fatias = []
    for i in range(len(palavra)+1):
        fatias.append((palavra[:i], palavra[i:]))
    palavras_geradas = insere_letras(fatias)
    return palavras_geradas

palavras_geradas = gerador_palavras(palavra_exemplo)
print(palavras_geradas)
# Out:
# ['algica', 'blgica', 'clgica', 'dlgica', 'elgica', 'flgica', 'glgica', 'hlgica', 'ilgica', 'jlgica', 'klgica', 'llgica', 'mlgica', 'nlgica', 'olgica', 'plgica', 'qlgica', 'rlgica', 'slgica', 'tlgica', 'ulgica', 'vlgica', 'wlgica', 'xlgica', 'ylgica', 'zlgica', 'àlgica', 'álgica', 'âlgica', 'ãlgica', 'èlgica', 'élgica', 'êlgica', 'ìlgica', 'ílgica', 'îlgica', 'òlgica', 'ólgica', 'ôlgica', 'õlgica', 'ùlgica', 'úlgica', 'ûlgica', 'çlgica']

# %%
# Definindo a frequencia que as palavras aparecem 

frequencia = nltk.FreqDist(lista_normalizada)
total_palavras = len(lista_normalizada)
frequencia.most_common(10)
# Out:
# [('de', 15494),
#  ('o', 13966),
#  ('que', 12225),
#  ('a', 11034),
#  ('e', 10478),
#  ('para', 7694),
#  ('um', 6346),
#  ('é', 5881),
#  ('uma', 5202),
#  ('do', 5116)]

# %%
# Definindo a função de probabilidade da palavra escrita ser a certa.

def probabilidade(palavra_gerada):
    return frequencia[palavra_gerada]/total_palavras

probabilidade("lógica")
# Out:
# 0.00022086039084673304

# %%
def corretor(palavra):
    palavras_geradas = gerador_palavras(palavra)
    palavra_correta = max(palavras_geradas, key = probabilidade)
    return palavra_correta

# %%
frequencia['lógica']
# Out:
# 87

# %%
corretor(palavra_exemplo)
# Out:
# 'algica'
